# %%
# !pip install fastf1
import pandas as pd
import fastf1

# %%
df = pd.read_csv(r"C:\Users\Aarnavi\OneDrive\Documents\f1-bayesian-predictor\data\raw\silverstone_2024.csv")
df
# Out:
#     Driver                 LapTime      Team      Compound  LapNumber  \
# 0      HAM  0 days 00:01:36.034000  Mercedes        MEDIUM        1.0
# 1      HAM  0 days 00:01:31.420000  Mercedes        MEDIUM        2.0
# 2      HAM  0 days 00:01:31.716000  Mercedes        MEDIUM        3.0
# 3      HAM  0 days 00:01:31.988000  Mercedes        MEDIUM        4.0
# 4      HAM  0 days 00:01:31.677000  Mercedes        MEDIUM        5.0
# ..     ...                     ...       ...           ...        ...
# 956    RUS  0 days 00:01:41.237000  Mercedes  INTERMEDIATE       30.0
# 957    RUS  0 days 00:01:41.902000  Mercedes  INTERMEDIATE       31.0
# 958    RUS  0 days 00:01:43.085000  Mercedes  INTERMEDIATE       32.0
# 959    RUS  0 days 00:01:46.221000  Mercedes  INTERMEDIATE       33.0
# 960    GAS                     NaN    Alpine        MEDIUM        1.0
#
#     PitOutTime               PitInTime
# 0          NaN                     NaN
# 1          NaN                     NaN
# ...

# %%
session2 = fastf1.get_session(2025, 'silverstone', 'R')
session2.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (212.97 MB) C:\Users\Aarnavi\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
session = fastf1.get_session(2024, 'silverstone', 'R')
session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (114.93 MB) C:\Users\Aarnavi\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
laps = session.laps
laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:59:51.778000    HAM           44 0 days 00:01:36.034000
# 1 0 days 01:01:23.198000    HAM           44 0 days 00:01:31.420000
# 2 0 days 01:02:54.914000    HAM           44 0 days 00:01:31.716000
# 3 0 days 01:04:26.902000    HAM           44 0 days 00:01:31.988000
# 4 0 days 01:05:58.579000    HAM           44 0 days 00:01:31.677000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:29.249000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:29.287000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:29.554000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:29.469000
#
#              Sector2Time  ... FreshTyre      Team           LapStartTime  \
# 0 0 days 00:00:37.703000  ...      True  Mercedes 0 days 00:58:15.512000
# ...

# %%
results = session.results
merged = laps.merge(results, left_on='Driver', right_on='Abbreviation')
merged
# Out:
#                     Time_x Driver DriverNumber_x                LapTime  \
# 0   0 days 00:59:51.778000    HAM             44 0 days 00:01:36.034000
# 1   0 days 01:01:23.198000    HAM             44 0 days 00:01:31.420000
# 2   0 days 01:02:54.914000    HAM             44 0 days 00:01:31.716000
# 3   0 days 01:04:26.902000    HAM             44 0 days 00:01:31.988000
# 4   0 days 01:05:58.579000    HAM             44 0 days 00:01:31.677000
# ..                     ...    ...            ...                    ...
# 956 0 days 01:45:56.213000    RUS             63 0 days 00:01:41.237000
# 957 0 days 01:47:38.115000    RUS             63 0 days 00:01:41.902000
# 958 0 days 01:49:21.200000    RUS             63 0 days 00:01:43.085000
# 959 0 days 01:51:07.421000    RUS             63 0 days 00:01:46.221000
# 960 0 days 00:59:50.955000    GAS             10                    NaT
#
#      LapNumber  Stint PitOutTime              PitInTime  \
# ...

# %%
results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 4             4      L NORRIS          NOR           norris          McLaren
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 18           18      L STROLL          STR           stroll     Aston Martin
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 23           23       A ALBON          ALB            albon         Williams
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# 2             2    L SARGEANT          SAR         sargeant         Williams
# ...
